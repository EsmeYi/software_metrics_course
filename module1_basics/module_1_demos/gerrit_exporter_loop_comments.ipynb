# %% [markdown]
# # Gerrit exporter
#
# This script tests how to extract comments for each revision from Gerrit. We need these comments to filter out comments that are related to the code and not to commit messages, not questions, no discussions.

# %%
from requests.auth import HTTPDigestAuth
from pygerrit2 import GerritRestAPI, HTTPBasicAuth
from IPython.display import clear_output
import requests
import pprint
import urllib

# %%
# A bit of config - repo and filename

gerrit_url = "https://gerrit.gromacs.org"
fileName = "./gerrit_reviews_gromacs.csv"

# pretty printer for json files
# used only when printing changes that have some problems
pp = pprint.PrettyPrinter(indent=2)

#auth = HTTPBasicAuth('username', 'password')
auth = None

# empty the file where we store the result
fileHandle = open(fileName, 
                  'w',
                  encoding = 'utf-8')

# header row
fileHandle.write('change_id;revision-id;filename;line;start_line;end_line;LOC;message\n')

# this line gets sets the parameters for the HTML API
rest = GerritRestAPI(url=gerrit_url, auth = auth)

# a set of parameters for the JSON API to get changes in batches of 500
start = 0
max_queries = 10000
has_more = True
no_errors = 0
queries = 0

# extracting changes, processing batch by batch
while has_more and queries < max_queries:
    try:
        changes = rest.get("/changes/?q=status:merged&o=ALL_FILES&o=ALL_REVISIONS&o=DETAILED_LABELS&start={}".format(start), 
                       headers={'Content-Type': 'application/json'})
        queries += 1

        number_of_changes = len(changes)

        # and if there are more pages of export
        # then we move on and get the next page
        # pp.pprint(changes[number_of_changes-1])
        if "_more_changes" in changes[number_of_changes-1]:
            has_more = True        
        else:
            has_more = False

        print("number of changes {}".format(number_of_changes))

        # here we process the changes
        for iIndex, change in enumerate(changes, start=1):
            changeID = change['id']

            if iIndex % 100 == 0:
                print("INFO: Extracting change: " + str(iIndex) + " of " + str(number_of_changes) + " starting at : " + str(start)) 

            revisions = change['revisions']

            for revID in list(revisions.keys()):
                currentComment = rest.get("/changes/{}/revisions/{}/comments".format(changeID,revID), headers={'Content-Type': 'application/json'})

                # not all revisions have comments, so we only look for those that have them
                if len(currentComment) > 0:                
                    for oneFile, oneComment in currentComment.items():                    
                        try:
                            # this code extracts information about the comment 
                            # things like which file and which lines
                            for oneCommentItem in oneComment:
                                strFile = oneFile

                                # a few if-s because not always all parameters are there
                                if 'line' in oneCommentItem:
                                    strLine = oneCommentItem['line']
                                else:
                                    strLine = ''

                                if 'message' in oneCommentItem:
                                    strMessage = oneCommentItem['message']
                                else:
                                    strMessage = ''

                                # if there is a specific line and characters as comments
                                if 'range' in oneCommentItem:
                                    strStartLine = oneCommentItem['range']['start_line']
                                    strStartChar = oneCommentItem['range']['start_character']
                                    strEndLine = oneCommentItem['range']['end_line']
                                    strEndChar = oneCommentItem['range']['end_character']                        
                                else:                            
                                    strStartLine = '0'
                                    strStartChar = '0'
                                    strEndLine = '0'
                                    strEndChar = '0'

                                # if we can extract something from a file
                                # then here is where we do it
                                if strLine != '':
                                    # we need the line below to properly encode the filename as URL
                                    urlFileID = urllib.parse.quote_plus(strFile)
                                    fileContentString = f'/changes/{changeID}/revisions/{revID}/files/{urlFileID}/content'
                                    fileContent = rest.get(fileContentString, headers={'Content-Type': 'application/json'})
                                    fileLines = fileContent.split("\n")

                                    # if we have the lines delimitations (comment that is linked to lines)
                                    if strStartLine != '0':
                                        iStartLine = int(strStartLine) - 1
                                        if strEndLine != '0':
                                            iEndLine = int(strEndLine) - 1  
                                        else: 
                                            iEndLine = len(fileLines) - 1

                                        for oneLine in fileLines[iStartLine:iEndLine]:
                                            strToCSV = str(changeID) + ";" + \
                                               str(revID) + ";" + \
                                               strFile + ";" + \
                                               str(strLine) + ";" + \
                                               str(strStartLine) + ";" + \
                                               str(strEndLine) + ";" + \
                                               oneLine.replace("\n", " _ ").replace('\r', '_').replace(';', '_') + ";" + \
                                               strMessage.replace("\n", " _ ").replace('\r', '_').replace(';', '_')
                                            fileHandle.write(strToCSV + "\n")
                                    elif int(strLine) < len(fileLines):                                
                                        # and if there are no delimitation, but there is a starting line
                                        # and the starting line is below the end of the file
                                        oneLine = fileLines[int(strLine)-1]
                                        strToCSV = str(changeID) + ";" + \
                                                   str(revID) + ";" + \
                                                   strFile + ";" + \
                                                   str(strLine) + ";" + \
                                                   str(strStartLine) + ";" + \
                                                   str(strEndLine) + ";" + \
                                                   oneLine.replace("\n", " _ ").replace('\r', '_').replace(';', '_') + ";" + \
                                                   strMessage.replace("\n", " _ ").replace('\r', '_').replace(';', '_')
                                        fileHandle.write(strToCSV + "\n")
                                else: 
                                    # there is no line specified, then we take the comment for the entire file
                                    for oneLine in fileLines:
                                            strToCSV = str(changeID) + ";" + \
                                               str(revID) + ";" + \
                                               strFile + ";" + \
                                               str(strLine) + ";" + \
                                               str(strStartLine) + ";" + \
                                               str(strEndLine) + ";" + \
                                               oneLine.replace("\n", " _ ").replace('\r', '_').replace(';', '_') + ";" + \
                                               strMessage.replace("\n", " _ ").replace('\r', '_').replace(';', '_')
                                            fileHandle.write(strToCSV + "\n")

                        except:
                            # this is a brutal exception handling, but we cannot check for all problems
                            print('INFO: Unhandled exception, moving on')
                            pp.pprint(oneComment)

    except:
        print('Moving on...')
    if has_more:
        start += 500
    #break
            
fileHandle.close()
print("Done !!!")
# Out:
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 0
# INFO: Extracting change: 200 of 500 starting at : 0
# INFO: Extracting change: 300 of 500 starting at : 0
# INFO: Extracting change: 400 of 500 starting at : 0
# INFO: Extracting change: 500 of 500 starting at : 0
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 500
# INFO: Extracting change: 200 of 500 starting at : 500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': 'bec70299_516b0e70',
#     'line': 116,
#     'message': 'This particular test was added recently to catch that xlC '
#                "can't compile this struct. I think that conforms to the "
#                'outcome of the previous discussion (that known problems can be '
#                "checked for). I'm fine with testing of general stuff being "
#                "removed here, but don't see a need to do so. The git log for "
#                'this file will make clear any other cases of testing for '
#                'specific issues.\n'
#                '\n'
#                'It is clearly valuable to users and devs that they get told up '
#                'front that they have to switch compilers, vs them thinking we '
#                'write broken code.',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2019-01-12 04:10:46.000000000'},
#   { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': 'bf6db6c3_ff3f0565',
#     'in_reply_to': '98d94a62_af86d8ef',
#     'line': 116,
#     'message': 'In the cmake 3.9.6 patch I extracted this particular failing '
#                'case and made it run for XL compiler, so we can agree to get '
#                'rid of this.',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2019-01-24 13:49:45.000000000'},
#   { 'author': { '_account_id': 1000000,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'roland.schulz@intel.com',
#                 'name': 'Roland Schulz',
#                 'username': 'rschulz'},
#     'id': '98d94a62_af86d8ef',
#     'in_reply_to': 'bec70299_516b0e70',
#     'line': 116,
#     'message': 'Two things were added in that patch. This test and the xlc '
#                'version check. The later of the two is way more useful. How '
#                'about we remove the test but keep the version check? I think '
#                "this example shows how the test wasn't very useful. xlc passed "
#                'all the test we already had but still failed to compile. Now '
#                'with the new test some other compiler will likely again fail '
#                'for some other reason. And if we anyhow have a version check I '
#                "don't see the reason to also have a compile test.",
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2019-01-14 17:28:16.000000000'}]
# INFO: Extracting change: 300 of 500 starting at : 500
# INFO: Extracting change: 400 of 500 starting at : 500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000533,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/fbcdea305be5ba9a4f86d7f1d44a7fcb.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/fbcdea305be5ba9a4f86d7f1d44a7fcb.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/fbcdea305be5ba9a4f86d7f1d44a7fcb.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'e.jjordan12@gmail.com',
#                 'name': 'Joe Jordan',
#                 'username': 'ejjordan'},
#     'id': '94eb78f2_75bc6aa8',
#     'line': 378,
#     'message': 'I think this can be removed.',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2018-12-04 10:15:18.000000000'},
#   { 'author': { '_account_id': 1000072,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/983b8047138cfe1180c592b606581126.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/983b8047138cfe1180c592b606581126.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/983b8047138cfe1180c592b606581126.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'spoel@xray.bmc.uu.se',
#                 'name': 'David van der Spoel',
#                 'username': 'dspoel'},
#     'id': '7b104270_46ffe948',
#     'in_reply_to': '94eb78f2_75bc6aa8',
#     'line': 378,
#     'message': 'Done',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2018-12-04 10:18:05.000000000'}]
# INFO: Extracting change: 500 of 500 starting at : 500
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 1000
# INFO: Extracting change: 200 of 500 starting at : 1000
# INFO: Extracting change: 300 of 500 starting at : 1000
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': 'a9b2cae2_f787a4d0',
#     'line': 1,
#     'message': "I suspect Erik's intent here was that the constants are extern "
#                "so that they have to be loaded, and can't get converted to "
#                'immediate arguments by the compiler',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2018-08-13 09:35:00.000000000'},
#   { 'author': { '_account_id': 1000111,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/ab9cfa5e90a4031f74ad3a84198a57cb.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/ab9cfa5e90a4031f74ad3a84198a57cb.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/ab9cfa5e90a4031f74ad3a84198a57cb.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'erik.lindahl@gmail.com',
#                 'name': 'Erik Lindahl',
#                 'username': 'lindahl'},
#     'id': 'b825d16f_64c3bfa0',
#     'in_reply_to': '4e4a8e9e_44f77452',
#     'line': 1,
#     'message': "I actually don't remember specifically if this has caused any "
#                'errors. As one comment says, the reason for introducing '
#                'constants instead of just using arbitrary numbers was to make '
#                'sure we exercise all bits.\n'
#                '\n'
#                'Constexpr will probably work, but on the other hand it also '
#                'makes sense to try and have the SIMD and reference data '
#                'processed as similarly as possible. \n'
#                '\n'
#                'No strong feelings, apart from the prior experience that '
#                'compilers seem to be very creative in how to mess up SIMD in '
#                'ways we did not think were possible :-)',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2018-08-16 18:32:17.000000000'},
#   { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': '6c54c01f_efab0353',
#     'in_reply_to': '9be8affc_1b95c33d',
#     'line': 1,
#     'message': 'Both forms of the constants will exercise all bits. so I '
#                "suggest we follow Roland's refactoring.",
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2018-08-18 00:07:14.000000000'},
#   { 'author': { '_account_id': 1000000,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'roland.schulz@intel.com',
#                 'name': 'Roland Schulz',
#                 'username': 'rschulz'},
#     'id': '4e4a8e9e_44f77452',
#     'in_reply_to': 'a9b2cae2_f787a4d0',
#     'line': 1,
#     'message': "I suspect the same. But I don't see why. 1) that isn't a safe "
#                'way to do it because ipo circumvents that (should be read from '
#                "file then) 2) whether they are constants and not can't change "
#                'the results for bugfree compiler. And if we use unit tests as '
#                'compiler checks than this should be commented and explained '
#                'why it is a safe way to test for a specific  (type) of '
#                'compiler bug. Because otherwise any valid refactoring will '
#                'potentially change the intention (compiler bugs often '
#                'disappear with very minor changes). I suggest to either leave '
#                'it is as. Or if this is not fulfilling the intentions I would '
#                'need a bit more information about what this is supposed to '
#                'achieve. So that I can either rework it in a better way or '
#                'have meaningful NOLINT comments.',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2018-08-13 17:40:04.000000000'},
#   { 'author': { '_account_id': 1000000,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'roland.schulz@intel.com',
#                 'name': 'Roland Schulz',
#                 'username': 'rschulz'},
#     'id': '9be8affc_1b95c33d',
#     'in_reply_to': 'b825d16f_64c3bfa0',
#     'line': 1,
#     'message': 'I suggest we go with this and if we have issue we go with '
#                'reading the constants from file. This should really prevent '
#                'compilers from compile time evaluation (even with ipo).\n'
#                '\n'
#                'The "on the other hand it also makes sense to try and have the '
#                'SIMD and reference data processed as similarly as possible" '
#                'might be a blessing in disguise. Because it might expose too '
#                'strict tests quicker. Because if constexpr makes a difference '
#                'than the compiler could in theory have done the same also '
#                'without it.\n'
#                '\n'
#                "Just curious: I don't understand why constants wouldn't "
#                'exercise all bits. The prior constants were round numbers '
#                "which didn't. But we could use the same numbers as constants "
#                'and I would thin that would have the same effect.',
#     'side': 'PARENT',
#     'unresolved': True,
#     'updated': '2018-08-17 00:21:15.000000000'}]
# INFO: Extracting change: 400 of 500 starting at : 1000
# INFO: Extracting change: 500 of 500 starting at : 1000
# number of changes 500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': '09209787_7291dc6c',
#     'line': 344,
#     'message': 'This barrier is missing in the combined source',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2018-05-14 08:02:21.000000000'},
#   { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': '9ec99bc5_505f905d',
#     'line': 408,
#     'message': 'This barrier is missing in the combined source',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2018-05-14 08:02:21.000000000'}]
# INFO: Extracting change: 100 of 500 starting at : 1500
# INFO: Extracting change: 200 of 500 starting at : 1500
# INFO: Extracting change: 300 of 500 starting at : 1500
# INFO: Extracting change: 400 of 500 starting at : 1500
# INFO: Extracting change: 500 of 500 starting at : 1500
# Moving on...
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 2500
# Moving on...
# Moving on...
# Moving on...
# number of changes 500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000000,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'roland.schulz@intel.com',
#                 'name': 'Roland Schulz',
#                 'username': 'rschulz'},
#     'id': 'c080b115_e721c256',
#     'line': 26,
#     'message': 'Unrelated: It might be a good idea to move contrib into its '
#                'own repository/download and contrib/fftw out of contrib.',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2015-06-04 17:07:39.000000000'}]
# INFO: Extracting change: 100 of 500 starting at : 4000
# INFO: Extracting change: 200 of 500 starting at : 4000
# INFO: Extracting change: 300 of 500 starting at : 4000
# INFO: Extracting change: 400 of 500 starting at : 4000
# INFO: Extracting change: 500 of 500 starting at : 4000
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 4500
# INFO: Extracting change: 200 of 500 starting at : 4500
# INFO: Extracting change: 300 of 500 starting at : 4500
# INFO: Extracting change: 400 of 500 starting at : 4500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000000,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/03ac75976b2af6ab56ebc39a3009402e.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'roland.schulz@intel.com',
#                 'name': 'Roland Schulz',
#                 'username': 'rschulz'},
#     'id': '46a77923_8bfa2d06',
#     'line': 1551,
#     'message': "Is the reasoning to remove it that we don't care to keep it "
#                'the same between rc and final? Or does it actually not effect '
#                "the result? It doesn't seem to matter for the regressiontests "
#                "but I don't see why it wouldn't effect it.",
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2014-04-30 02:04:12.000000000'},
#   { 'author': { '_account_id': 1000036,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/8c65bdab337b8aa043bd470d3cbf3531.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'mark.j.abraham@gmail.com',
#                 'name': 'Mark Abraham',
#                 'username': 'mabraham'},
#     'id': '26d60583_aaf56f1a',
#     'in_reply_to': '46a77923_8bfa2d06',
#     'line': 1551,
#     'message': 'We kept this in r46 to keep some minor behaviour consistent.\n'
#                '\n'
#                'By omitting this in r50, we are actually keeping the behaviour '
#                'of rc and final consistent, modulo the bug fix - see this '
#                'function in git diff 53fc9d0 -- src/gromacs/mdlib/coupling.c. '
#                'Since the r50 tests are already generated with the new RNG, we '
#                'should expect those tests to continue to pass.',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2014-05-01 11:43:05.000000000'}]
# INFO: Extracting change: 500 of 500 starting at : 4500
# Moving on...
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 5500
# INFO: Extracting change: 200 of 500 starting at : 5500
# INFO: Extracting change: 300 of 500 starting at : 5500
# INFO: Extracting change: 400 of 500 starting at : 5500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000067,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/142557d90d36eba60017f47ef02c2170.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/142557d90d36eba60017f47ef02c2170.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/142557d90d36eba60017f47ef02c2170.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'junghans@votca.org',
#                 'name': 'Christoph Junghans',
#                 'username': 'junghans'},
#     'id': 'AAAIQn%2F%2F%2F%2Bg%3D',
#     'line': 44,
#     'message': 'The quotes are a text file, so why it this program actually '
#                'needed?',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2013-02-07 20:58:45.000000000'}]
# INFO: Extracting change: 500 of 500 starting at : 5500
# Moving on...
# number of changes 500
# INFO: Extracting change: 100 of 500 starting at : 6500
# INFO: Unhandled exception, moving on
# [ { 'author': { '_account_id': 1000105,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'pall.szilard@gmail.com',
#                 'name': 'Szilárd Páll',
#                 'username': 'pszilard'},
#     'id': 'AAACkH%2F%2F%2F44%3D',
#     'line': 14,
#     'message': 'We\'ve been adding new headers lately without the "VERSION" '
#                'line and bumped copyright (2004->2012).',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2012-03-01 16:22:40.000000000'},
#   { 'author': { '_account_id': 1000105,
#                 'avatars': [ { 'height': 26,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=26'},
#                              { 'height': 32,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=32'},
#                              { 'height': 100,
#                                'url': 'https://www.gravatar.com/avatar/64800e01011461057e9e5653797dd8cd.jpg?d=identicon&r=pg&s=100'}],
#                 'email': 'pall.szilard@gmail.com',
#                 'name': 'Szilárd Páll',
#                 'username': 'pszilard'},
#     'id': 'AAACkH%2F%2F%2F4o%3D',
#     'line': 14,
#     'message': 'please remove the version line and bump the year from '
#                '2004->2012',
#     'side': 'PARENT',
#     'unresolved': False,
#     'updated': '2012-03-01 16:22:40.000000000'}]
# INFO: Extracting change: 200 of 500 starting at : 6500
# INFO: Extracting change: 300 of 500 starting at : 6500
# INFO: Extracting change: 400 of 500 starting at : 6500
# INFO: Extracting change: 500 of 500 starting at : 6500
# number of changes 164
# INFO: Extracting change: 100 of 164 starting at : 7000
# Done !!!
